# %% [markdown]
# # Example Usage - Differential Evolution (DE)

# %% [markdown]
# Auto Reload Submodules

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Import path

# %%
import sys
import os
import numpy as np

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# Set up logger

# %%
import logging

logging.basicConfig(
    encoding="utf-8",
    filemode="a",
    format="[{asctime}] [{levelname}] {message}",
    style="{",
    datefmt="%Y-%m-%d, %H:%M",
    level=logging.INFO,
)

logger = logging.getLogger()
logger.info("Hello logging!")
# Out:
# [2025-07-09, 22:19] [INFO] Hello logging!

# %% [markdown]
# Now, we can define a set of Genes using:

# %%
from pyeas._population import Genes

Genes(bounds=(-1,2), number=10)
# Out:
# Genes(bounds=(-1, 2), number=10)

# %% [markdown]
# Next, we define the structure of a 'genome' or member my making a list of genes:

# %%
member = [
    Genes(bounds=(-1,0), number=2),
    Genes(bounds=(4,8), number=1),
    Genes(bounds=(0,1), number=2),
]

# %% [markdown]
# Then, initialise  the population:

# %%
from pyeas._population import Population

pop = Population(
    size=3,
    member=member,
    seed=42,
)
# Out:
# [2025-07-09, 22:27] [INFO] [Population] Each Member has 5 genes
# [2025-07-09, 22:27] [INFO] [Population] Gene members: N=2 ∈(-1, 0), N=1 ∈(4, 8), N=2 ∈(0, 1)
# [2025-07-09, 22:27] [INFO] [Population] Population size (number of members) is 3

# %% [markdown]
# The generated population is:

# %%
print(np.shape(pop.population))
pop.population
# Out:
# (3, 5)
# array([[-0.22604, -0.56112,  7.4344 ,  0.69737,  0.09418],
#        [-0.02438, -0.23886,  7.14424,  0.12811,  0.45039],
#        [-0.6292 , -0.07324,  6.57548,  0.82276,  0.44341]])

# %% [markdown]
# Now, the raw population is normalised to between zero and one:

# %%
print(np.shape(pop.population_raw))
pop.population_raw
# Out:
# (3, 5)
# array([[0.77396, 0.43888, 0.8586 , 0.69737, 0.09418],
#        [0.97562, 0.76114, 0.78606, 0.12811, 0.45039],
#        [0.3708 , 0.92676, 0.64387, 0.82276, 0.44341]])

# %% [markdown]
# This is scaled using the bounds:

# %%
pop.bounds
# Out:
# array([[-1,  0],
#        [-1,  0],
#        [ 4,  8],
#        [ 0,  1],
#        [ 0,  1]])

# %% [markdown]
# Finally, we can try and set a new population, we catch this setter and ensure several checks are run:

# %%
pop.population = [[1,2], [4,5,6]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 pop.population = [[1,2], [4,5,6]]
#
# File c:\Users\bened\Documents\GitHub\pyeas\pyeas\_population.py:90, in Population.population(self, arr)
#      86 @population.setter
#      87 def population(self, arr:np.ndarray):
#      89     if np.shape(arr)[0] != self.size:
# ---> 90         raise ValueError(f"Array to set as population must have {self.size} rows, but is shape: {np.shape(arr)}")
#      92     if self.flatten_gene_groupings is False:
#      93         if np.shape(arr)[1] != self.n_groups:
#
# TypeError: Must set the population using an array, not a <class 'list'>

# %%
pop.population = np.array([[-0.22604, -0.56112,  7.4344 ,  0.69737,  0.09418,  0.09418],
       [-0.02438, -0.23886,  7.14424,  0.12811,  0.45039,  0.09418],
       [-0.6292 , -0.07324,  6.57548,  0.82276,  0.44341,  0.09418]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 pop.population = np.array([[-0.22604, -0.56112,  7.4344 ,  0.69737,  0.09418,  0.09418],
#       2        [-0.02438, -0.23886,  7.14424,  0.12811,  0.45039,  0.09418],
#       3        [-0.6292 , -0.07324,  6.57548,  0.82276,  0.44341,  0.09418]])
#
# File c:\Users\bened\Documents\GitHub\pyeas\pyeas\_population.py:102, in Population.population(self, arr)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# ValueError: Array to set as population must have 5 genes per row, but is shape: (3, 6)

# %% [markdown]
# If we exceed the limits (i.e., 0 & 1 for the normalised population) of the bounds, the values are clipped with logging warnings:

# %%
pop.population = pop.population*1.8
pop.population
# Out:
# [2025-07-09, 22:34] [WARNING] [Population] [Setter] Normalised population to set contains values below 0! Clipping...
# [2025-07-09, 22:34] [WARNING] [Population] [Setter] Normalised population to set contains values above 1! Clipping...
# [2025-07-09, 22:34] [INFO] [Population] [Setter] Finished setting population!
# array([[-0.40687, -1.     ,  8.     ,  1.     ,  0.16952],
#        [-0.04388, -0.42995,  8.     ,  0.2306 ,  0.8107 ],
#        [-1.     , -0.13183,  8.     ,  1.     ,  0.79814]])

# %% [markdown]
# Next, consider the same population but with the genes remained in a grouping structure (i.e., not flattened):

# %%
pop_grouped = Population(
    size=3,
    member=member,
    seed=42,
    flatten_gene_groupings=False,
)
# Out:
# [2025-07-09, 22:26] [INFO] [Population] Members grouped in: [2, 1, 2]
# [2025-07-09, 22:26] [INFO] [Population] Each Member has 5 genes
# [2025-07-09, 22:26] [INFO] [Population] Gene members: N=2 ∈(-1, 0), N=1 ∈(4, 8), N=2 ∈(0, 1)
# [2025-07-09, 22:26] [INFO] [Population] Population size (number of members) is 3

# %%
print(np.shape(pop_grouped.population))
pop_grouped.population
# Out:
# (3, 3)
# array([[array([-0.22604, -0.56112]), array([7.4344]),
#         array([0.69737, 0.09418])],
#        [array([-0.02438, -0.23886]), array([7.14424]),
#         array([0.12811, 0.45039])],
#        [array([-0.6292 , -0.07324]), array([6.57548]),
#         array([0.82276, 0.44341])]], dtype=object)

# %%
pop_grouped.population
# Out:
# array([[array([-0.22604, -0.56112]), array([7.4344]),
#         array([0.69737, 0.09418])],
#        [array([-0.02438, -0.23886]), array([7.14424]),
#         array([0.12811, 0.45039])],
#        [array([-0.6292 , -0.07324]), array([6.57548]),
#         array([0.82276, 0.44341])]], dtype=object)

# %% [markdown]
# We can similarly assign (and catch) setting to a new population value:

# %%
pop_grouped.population = np.array(
    [
        [np.array([-0.22604, -0.56112]), np.array([7.4344]), np.array([0.69737, 0.09418])],
        [np.array([-0.02438, -0.23886]), np.array([7.14424]),np.array([0.12811, 0.45039])],
        [np.array([-0.6292 , -0.07324]), np.array([6.57548]),np.array([0.82276, 0.44341])], 
        [np.array([-0.6292 , -0.07324]), np.array([6.57548]),np.array([0.82276, 0.44341])]
    ],
    dtype=object,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 pop_grouped.population = np.array(
#       2     [
#       3         [np.array([-0.22604, -0.56112]), np.array([7.4344]), np.array([0.69737, 0.09418])],
#       4         [np.array([-0.02438, -0.23886]), np.array([7.14424]),np.array([0.12811, 0.45039])],
#       5         [np.array([-0.6292 , -0.07324]), np.array([6.57548]),np.array([0.82276, 0.44341])],
#       6         [np.array([-0.6292 , -0.07324]), np.array([6.57548]),np.array([0.82276, 0.44341])]
#       7     ],
#       8     dtype=object,
#       9 )
#
# File c:\Users\bened\Documents\GitHub\pyeas\pyeas\_population.py:104, in Population.population(self, arr)
#     101     raise TypeError(f"Must set the population using an array, not a {type(arr)}")
#     103 if np.shape(arr)[0] != self.size:
# --> 104     raise ValueError(f"Array to set as population must have {self.size} rows, but is shape: {np.shape(arr)}")
#     106 if self.flatten_gene_groupings is False:
#     107     if np.shape(arr)[1] != self.n_groups:
#
# ValueError: Array to set as population must have 3 rows, but is shape: (4, 3)

# %%
pop_grouped.population = np.array(
    [
        [np.array([-0.22604, -0.56112]), np.array([7.4344]), np.array([0.69737, 0.09418])],
        [np.array([-0.02438, -0.23886]), np.array([7.14424]),np.array([0.12811, 0.45039])],
        [np.array([-0.6292 , -0.07324, 6.57548]),np.array([0.82276, 0.44341])], 
    ],
    dtype=object,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 pop_grouped.population = np.array(
#       2     [
#       3         [np.array([-0.22604, -0.56112]), np.array([7.4344]), np.array([0.69737, 0.09418])],
#       4         [np.array([-0.02438, -0.23886]), np.array([7.14424]),np.array([0.12811, 0.45039])],
#       5         [np.array([-0.6292 , -0.07324,6.57548]),np.array([0.82276, 0.44341])],
#       6     ],
#       7     dtype=object,
#       8 )
#
# File c:\Users\bened\Documents\GitHub\pyeas\pyeas\_population.py:108, in Population.population(self, arr)
#     106 if self.flatten_gene_groupings is False:
#     107     if np.shape(arr)[1] != self.n_groups:
# --> 108         raise ValueError(f"Array to set as population must have {self.n_groups} groups per row, but is shape: {np.shape(arr)}")
#     109     arr = self.ungroup(arr)
#     111 else:
#
# ValueError: Array must be 3 members by 3 sub array groupings, but is shape: (3,)

# %%
pop_grouped.population = pop_grouped.population*2
pop_grouped.population
# Out:
# [2025-07-09, 23:01] [WARNING] [Population] [Setter] Normalised population to set contains values below 0! Clipping...
# [2025-07-09, 23:01] [WARNING] [Population] [Setter] Normalised population to set contains values above 1! Clipping...
# [2025-07-09, 23:01] [INFO] [Population] [Setter] Finished setting population!
# array([[array([-0.45208, -1.     ]), array([8.]),
#         array([1.     , 0.18836])],
#        [array([-0.04876, -0.47772]), array([8.]),
#         array([0.25622, 0.90078])],
#        [array([-1.     , -0.14648]), array([8.]),
#         array([1.     , 0.88682])]], dtype=object)

# %% [markdown]
# We can retain the raw population:

# %%
print(np.shape(pop_grouped.population_raw))
pop_grouped.population_raw
# Out:
# (3, 5)
# array([[0.54792, 0.     , 1.     , 1.     , 0.18836],
#        [0.95124, 0.52228, 1.     , 0.25622, 0.90078],
#        [0.     , 0.85352, 1.     , 1.     , 0.88682]])
